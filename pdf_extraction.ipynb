# %%
from tabula import read_pdf

# %%
import tabula 
import pandas as pd

# %%
path= r'C:\Users\SIMRAN\India Tourism Statistics 2019.pdf'
df= tabula.read_pdf(path, pages= '116')

# %%
df
# Out:
# [    s.\rno.              state/ ut       2017 2018 (r) Growth rate Unnamed: 0  \
#  0       NaN                    NaN   domestic  Foreign    domestic    Foreign
#  1       6.0             chandigarh    1425781    31832     1538796      39681
#  2       7.0           chhattisgarh   17350030     6701    19329501      14399
#  3       8.0  dadra & nagar\rHaveli     614182     1908      609435       1608
#  4       9.0            daman & diu     858131     5535      898824       5694
#  5      10.0                delhi *   29114423  2740502    29114423    2740502
#  6      11.0                    Goa    6895234   842220     7081559     933841
#  7      12.0                Gujarat   48343121   448853    54369873     513113
#  8      13.0                Haryana    6050325   193381     4888952      73977
#  9      14.0      Himachal\rPradesh   19130541   470992    16093935     356568
#  10     15.0              Jharkhand   33723185   170987    35408822     175801
# ...

# %%
len(df)
# Out:
# 2

# %%
df[1]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Domestic Tourism
# 102India Tourism Statistics, 2019, Unnamed: 1]
# Index: []

# %%
df[0].columns= [['no', 'state','2017_domestic','2017_foreign','2018_domestic','2018_foreign','growth_rate_d','growth_rate_f']]

# %%
df[0].drop(columns=['no'], inplace=True)
# Out:
# C:\Users\SIMRAN\Anaconda3\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
df[0].drop([0], inplace=True)

# %%
df[0]
# Out:
#                     state 2017_domestic 2017_foreign 2018_domestic  \
# 1              chandigarh       1425781        31832       1538796
# 2            chhattisgarh      17350030         6701      19329501
# 3   dadra & nagar\rHaveli        614182         1908        609435
# 4             daman & diu        858131         5535        898824
# 5                 delhi *      29114423      2740502      29114423
# 6                     Goa       6895234       842220       7081559
# 7                 Gujarat      48343121       448853      54369873
# 8                 Haryana       6050325       193381       4888952
# 9       Himachal\rPradesh      19130541       470992      16093935
# 10              Jharkhand      33723185       170987      35408822
# 11                    J&K      14235473        79765      17076315
# 12              Karnataka     179980191       498148     214306456
# 13                 Kerala      14673520      1091870      15604661
# ...

# %%
table_2= df[0].copy()

# %%
path= r'C:\Users\SIMRAN\India Tourism Statistics 2019.pdf'
df2= tabula.read_pdf(path, pages= '115')
# Out:
# Got stderr: May 12, 2020 10:08:50 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 1.8.0_131
# May 12, 2020 10:08:51 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# May 12, 2020 10:08:51 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# May 12, 2020 10:08:51 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# May 12, 2020 10:08:51 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# May 12, 2020 10:08:51 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")

# %%
df2[0]
# Out:
#     S.       State/ UT       2017 Unnamed: 0          2018 (R)  \
# 0  No.             NaN   Domestic    Foreign  Domestic Foreign
# 1    1       Andaman &     471919      15313      498279 15242
# 2  NaN  Nicobar Island        NaN        NaN               NaN
# 3    2  Andhra Pradesh  165433898     271362  194767874 281083
# 4    3       Arunachal     444005       7147       512436 7653
# 5  NaN         Pradesh        NaN        NaN               NaN
# 6    4           Assam    6052667      21760     5856282 36846
# 7    5           Bihar   32414063    1082705  33621613 1087971
#
#         Growth Rate
# 0  Domestic Foreign
# 1        5.59 -0.46
# 2               NaN
# 3        17.73 3.58
# 4        15.41 7.08
# 5               NaN
# 6       -3.24 69.33
# 7         3.73 0.49

# %%
path= r'C:\Users\SIMRAN\India Tourism Statistics 2019.pdf'
df3= tabula.read_pdf(path, pages= '115', stream=True)
# Out:
# Got stderr: May 12, 2020 10:29:05 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 1.8.0_131
# May 12, 2020 10:29:05 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# May 12, 2020 10:29:05 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# May 12, 2020 10:29:05 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# May 12, 2020 10:29:05 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# May 12, 2020 10:29:05 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")

# %%
path= r'C:\Users\SIMRAN\India Tourism Statistics 2019.pdf'
df3= tabula.read_pdf(path,output_format="json" ,pages= '115')
# Out:
# Got stderr: May 12, 2020 11:11:46 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 1.8.0_131
# May 12, 2020 11:11:46 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# May 12, 2020 11:11:46 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# May 12, 2020 11:11:46 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# May 12, 2020 11:11:46 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# May 12, 2020 11:11:46 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")

# %%
top= None
left=None
bottom=None
right=None

# %%
top= df3[0]['top']
left= df3[0]['left']
bottom= df3[0]['height'] +top
right= df3[0]['width']+left

# %%
print(top)
print(left)
print(bottom)
print(right)
# Out:
# 462.0
# 58.0
# 606.0
# 460.0

# %%
path= r'C:\Users\SIMRAN\India Tourism Statistics 2019.pdf'
df3= tabula.read_pdf(path,output_format="json" ,pages= '117')

# %%
path= r'C:\Users\SIMRAN\India Tourism Statistics 2019.pdf'
df3= tabula.read_pdf(path ,pages= '115', area=(480.0,58.0,606.0,460.0))

# %%
df3[0]
# Out:
#   Unnamed: 0                 Unnamed: 1   Domestic   Foreign  Domestic.1  \
# 0          1  Andaman &\rNicobar Island     471919     15313      498279
# 1          2             Andhra Pradesh  165433898    271362   194767874
# 2          3         Arunachal\rPradesh     444005      7147      512436
# 3          4                      Assam    6052667     21760     5856282
# 4      Bihar                   32414063    1082705  33621613     1087971
#
#    Foreign.1  Domestic.2  Foreign.2
# 0   15242.00        5.59      -0.46
# 1  281083.00       17.73       3.58
# 2    7653.00       15.41       7.08
# 3   36846.00       -3.24      69.33
# 4       3.73        0.49        NaN

# %%
df3[0].columns= [['no', 'state','2017_domestic','2017_foreign','2018_domestic','2018_foreign','growth_rate_d','growth_rate_f']]

# %%
df3[0]
# Out:
#       no                      state 2017_domestic 2017_foreign 2018_domestic  \
# 0      1  Andaman &\rNicobar Island        471919        15313        498279
# 1      2             Andhra Pradesh     165433898       271362     194767874
# 2      3         Arunachal\rPradesh        444005         7147        512436
# 3      4                      Assam       6052667        21760       5856282
# 4  Bihar                   32414063       1082705     33621613       1087971
#
#   2018_foreign growth_rate_d growth_rate_f
# 0     15242.00          5.59         -0.46
# 1    281083.00         17.73          3.58
# 2      7653.00         15.41          7.08
# 3     36846.00         -3.24         69.33
# 4         3.73          0.49           NaN

# %%
df3[0].replace(df3[0].loc[4,'growth_rate_d'],df3[0].loc[4,'no'] )
# Out:
#       no                      state 2017_domestic 2017_foreign 2018_domestic  \
# 0      1  Andaman &\rNicobar Island        471919        15313        498279
# 1      2             Andhra Pradesh     165433898       271362     194767874
# 2      3         Arunachal\rPradesh        444005         7147        512436
# 3      4                      Assam       6052667        21760       5856282
# 4  Bihar                   32414063       1082705     33621613       1087971
#
#   2018_foreign growth_rate_d growth_rate_f
# 0     15242.00          5.59         -0.46
# 1    281083.00         17.73          3.58
# 2      7653.00         15.41          7.08
# 3     36846.00         -3.24         69.33
# 4         3.73          0.49           NaN

# %%
df3[0]
# Out:
#       no                      state 2017_domestic 2017_foreign 2018_domestic  \
# 0      1  Andaman &\rNicobar Island        471919        15313        498279
# 1      2             Andhra Pradesh     165433898       271362     194767874
# 2      3         Arunachal\rPradesh        444005         7147        512436
# 3      4                      Assam       6052667        21760       5856282
# 4  Bihar                   32414063       1082705     33621613       1087971
#
#   2018_foreign growth_rate_d growth_rate_f
# 0     15242.00          5.59         -0.46
# 1    281083.00         17.73          3.58
# 2      7653.00         15.41          7.08
# 3     36846.00         -3.24         69.33
# 4         3.73          0.49           NaN

# %%
table_1= df3[0].copy()

# %%
table_1 =pd.DataFrame(table_1)

# %%
table_1.set
# Out:
#       no                      state 2017_domestic 2017_foreign 2018_domestic  \
# 0      1  Andaman &\rNicobar Island        471919        15313        498279
# 1      2             Andhra Pradesh     165433898       271362     194767874
# 2      3         Arunachal\rPradesh        444005         7147        512436
# 3      4                      Assam       6052667        21760       5856282
# 4  Bihar                   32414063       1082705     33621613       1087971
#
#   2018_foreign growth_rate_d growth_rate_f
# 0     15242.00          5.59         -0.46
# 1    281083.00         17.73          3.58
# 2      7653.00         15.41          7.08
# 3     36846.00         -3.24         69.33
# 4         3.73          0.49           NaN

# %%
table_1.at[4,'growth_rate_f']=0.49
table_1.at[4,'growth_rate_d']=3.73
table_1.at[4,'2018_foreign']=1087971
table_1.at[4,'2018_domestic']=33621613
table_1.at[4,'2017_foreign']= 1082705
table_1.at[4,'2017_domestic']=32414063
table_1.at[4, 'state']= 'Bihar'

# %%
table_1
# Out:
#       no                      state 2017_domestic 2017_foreign 2018_domestic  \
# 0      1  Andaman &\rNicobar Island        471919        15313        498279
# 1      2             Andhra Pradesh     165433898       271362     194767874
# 2      3         Arunachal\rPradesh        444005         7147        512436
# 3      4                      Assam       6052667        21760       5856282
# 4  Bihar                      Bihar      32414063      1082705      33621613
#
#   2018_foreign growth_rate_d growth_rate_f
# 0      15242.0          5.59         -0.46
# 1     281083.0         17.73          3.58
# 2       7653.0         15.41          7.08
# 3      36846.0         -3.24         69.33
# 4    1087971.0          3.73          0.49

# %%
df3[0].loc[4,'no']
# Out:
# no    Bihar
# Name: 4, dtype: object

# %%
path= r'C:\Users\SIMRAN\India Tourism Statistics 2019.pdf'
df4= tabula.read_pdf(path,output_format="json" ,pages= '117')

# %%
top= df4[0]['top']
left= df4[0]['left']
bottom= df4[0]['height'] +top
right= df4[0]['width']+left

# %%
print(top)
print(left)
print(bottom)
print(right)
# Out:
# 54.30358
# 54.18411
# 138.13171262939454
# 460.38781483398435

# %%
path= r'C:\Users\SIMRAN\India Tourism Statistics 2019.pdf'
df4= tabula.read_pdf(path ,pages= '117')

# %%
df4[0]
# Out:
#    S.\rNo.    State/ UT        2017  2018 (R) Growth Rate Unnamed: 0  \
# 0      NaN     Domestic     Foreign  Domestic     Foreign   Domestic
# 1     35.0  Uttarakhand    34359989    133725    35609650     151320
# 2     36.0  West Bengal    79630345   1574915    85657365    1617105
# 3      NaN        Total  1657546152  26886684  1854933384   28872384
#
#   Unnamed: 1  Unnamed: 2
# 0    Foreign         NaN
# 1       3.64       13.16
# 2       7.57        2.68
# 3      11.91        7.39

# %%
df4[0].columns= [['no', 'state','2017_domestic','2017_foreign','2018_domestic','2018_foreign','growth_rate_d','growth_rate_f']]

# %%
df4[0]
# Out:
#      no        state 2017_domestic 2017_foreign 2018_domestic 2018_foreign  \
# 0   NaN     Domestic       Foreign     Domestic       Foreign     Domestic
# 1  35.0  Uttarakhand      34359989       133725      35609650       151320
# 2  36.0  West Bengal      79630345      1574915      85657365      1617105
# 3   NaN        Total    1657546152     26886684    1854933384     28872384
#
#   growth_rate_d growth_rate_f
# 0       Foreign           NaN
# 1          3.64         13.16
# 2          7.57          2.68
# 3         11.91          7.39

# %%
df4[0].drop(columns=['no'], inplace=True)
df4[0].drop(0, inplace=True)
# Out:
# C:\Users\SIMRAN\Anaconda3\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
df4[0]
# Out:
#          state 2017_domestic 2017_foreign 2018_domestic 2018_foreign  \
# 1  Uttarakhand      34359989       133725      35609650       151320
# 2  West Bengal      79630345      1574915      85657365      1617105
# 3        Total    1657546152     26886684    1854933384     28872384
#
#   growth_rate_d growth_rate_f
# 1          3.64         13.16
# 2          7.57          2.68
# 3         11.91          7.39

# %%
table_3= df4[0].copy()

# %%
table_1
# Out:
#       no                      state 2017_domestic 2017_foreign 2018_domestic  \
# 0      1  Andaman &\rNicobar Island        471919        15313        498279
# 1      2             Andhra Pradesh     165433898       271362     194767874
# 2      3         Arunachal\rPradesh        444005         7147        512436
# 3      4                      Assam       6052667        21760       5856282
# 4  Bihar                      Bihar      32414063      1082705      33621613
#
#   2018_foreign growth_rate_d growth_rate_f
# 0      15242.0          5.59         -0.46
# 1     281083.0         17.73          3.58
# 2       7653.0         15.41          7.08
# 3      36846.0         -3.24         69.33
# 4    1087971.0          3.73          0.49

# %%
table_1.drop(columns=['no'], inplace=True)
# Out:
# C:\Users\SIMRAN\Anaconda3\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
table_2
# Out:
#                     state 2017_domestic 2017_foreign 2018_domestic  \
# 1              chandigarh       1425781        31832       1538796
# 2            chhattisgarh      17350030         6701      19329501
# 3   dadra & nagar\rHaveli        614182         1908        609435
# 4             daman & diu        858131         5535        898824
# 5                 delhi *      29114423      2740502      29114423
# 6                     Goa       6895234       842220       7081559
# 7                 Gujarat      48343121       448853      54369873
# 8                 Haryana       6050325       193381       4888952
# 9       Himachal\rPradesh      19130541       470992      16093935
# 10              Jharkhand      33723185       170987      35408822
# 11                    J&K      14235473        79765      17076315
# 12              Karnataka     179980191       498148     214306456
# 13                 Kerala      14673520      1091870      15604661
# ...

# %%
table_3
# Out:
#          state 2017_domestic 2017_foreign 2018_domestic 2018_foreign  \
# 1  Uttarakhand      34359989       133725      35609650       151320
# 2  West Bengal      79630345      1574915      85657365      1617105
# 3        Total    1657546152     26886684    1854933384     28872384
#
#   growth_rate_d growth_rate_f
# 1          3.64         13.16
# 2          7.57          2.68
# 3         11.91          7.39

# %%
table_N =table_1.append(table_2,ignore_index=True)

# %%
table_N
# Out:
#                         state 2017_domestic 2017_foreign 2018_domestic  \
# 0   Andaman &\rNicobar Island        471919        15313        498279
# 1              Andhra Pradesh     165433898       271362     194767874
# 2          Arunachal\rPradesh        444005         7147        512436
# 3                       Assam       6052667        21760       5856282
# 4                       Bihar      32414063      1082705      33621613
# 5                  chandigarh       1425781        31832       1538796
# 6                chhattisgarh      17350030         6701      19329501
# 7       dadra & nagar\rHaveli        614182         1908        609435
# 8                 daman & diu        858131         5535        898824
# 9                     delhi *      29114423      2740502      29114423
# 10                        Goa       6895234       842220       7081559
# 11                    Gujarat      48343121       448853      54369873
# ...

# %%
table_final= table_N.append(table_3, ignore_index=True)

# %%
table_final
# Out:
#                         state 2017_domestic 2017_foreign 2018_domestic  \
# 0   Andaman &\rNicobar Island        471919        15313        498279
# 1              Andhra Pradesh     165433898       271362     194767874
# 2          Arunachal\rPradesh        444005         7147        512436
# 3                       Assam       6052667        21760       5856282
# 4                       Bihar      32414063      1082705      33621613
# 5                  chandigarh       1425781        31832       1538796
# 6                chhattisgarh      17350030         6701      19329501
# 7       dadra & nagar\rHaveli        614182         1908        609435
# 8                 daman & diu        858131         5535        898824
# 9                     delhi *      29114423      2740502      29114423
# 10                        Goa       6895234       842220       7081559
# 11                    Gujarat      48343121       448853      54369873
# ...

# %%
table_final.columns=[['state','domestic_revenue_17','foreign_revenue_17', 'domestic_revenue_18','foreign_revenue_18','domestic_growth_rate', 'foreign_growth_rate']]

# %%
table_final
# Out:
#                         state domestic_revenue_17 foreign_revenue_17  \
# 0   Andaman &\rNicobar Island              471919              15313
# 1              Andhra Pradesh           165433898             271362
# 2          Arunachal\rPradesh              444005               7147
# 3                       Assam             6052667              21760
# 4                       Bihar            32414063            1082705
# 5                  chandigarh             1425781              31832
# 6                chhattisgarh            17350030               6701
# 7       dadra & nagar\rHaveli              614182               1908
# 8                 daman & diu              858131               5535
# 9                     delhi *            29114423            2740502
# 10                        Goa             6895234             842220
# 11                    Gujarat            48343121             448853
# 12                    Haryana             6050325             193381
# ...

# %%
table_final= pd.DataFrame(table_final)

# %%
table_final.reset_index(inplace=True)

# %%
table_final.head()
# Out:
#   index                      state domestic_revenue_17 foreign_revenue_17  \
# 0     0  Andaman &\rNicobar Island              471919              15313
# 1     1             Andhra Pradesh           165433898             271362
# 2     2         Arunachal\rPradesh              444005               7147
# 3     3                      Assam             6052667              21760
# 4     4                      Bihar            32414063            1082705
#
#   domestic_revenue_18 foreign_revenue_18 domestic_growth_rate  \
# 0              498279              15242                 5.59
# 1           194767874             281083                17.73
# 2              512436               7653                15.41
# 3             5856282              36846                -3.24
# 4            33621613        1.08797e+06                 3.73
#
#   foreign_growth_rate
# 0               -0.46
# 1                3.58
# 2                7.08
# 3               69.33
# 4                0.49

# %%
table_final.drop(columns=['index'], inplace=True)
# Out:
# C:\Users\SIMRAN\Anaconda3\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
table_final.head()
# Out:
#                        state domestic_revenue_17 foreign_revenue_17  \
# 0  Andaman &\rNicobar Island              471919              15313
# 1             Andhra Pradesh           165433898             271362
# 2         Arunachal\rPradesh              444005               7147
# 3                      Assam             6052667              21760
# 4                      Bihar            32414063            1082705
#
#   domestic_revenue_18 foreign_revenue_18 domestic_growth_rate  \
# 0              498279              15242                 5.59
# 1           194767874             281083                17.73
# 2              512436               7653                15.41
# 3             5856282              36846                -3.24
# 4            33621613        1.08797e+06                 3.73
#
#   foreign_growth_rate
# 0               -0.46
# 1                3.58
# 2                7.08
# 3               69.33
# 4                0.49

# %%
table_final.columns
# Out:
# MultiIndex([(               'state',),
#             ( 'domestic_revenue_17',),
#             (  'foreign_revenue_17',),
#             ( 'domestic_revenue_18',),
#             (  'foreign_revenue_18',),
#             ('domestic_growth_rate',),
#             ( 'foreign_growth_rate',)],
#            )

# %%
table_final.to_excel(r'F:\Analytics\transerve assignmnts\tourism_data\tourism_2018_revenue.xlsx')

# %%
df= pd.read_excel(r'F:\Analytics\transerve assignmnts\tourism_data\tourism_2018_revenue.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0                      state  domestic_revenue_17  \
# 0         NaN                        NaN                  NaN
# 1         0.0  Andaman &\rNicobar Island             471919.0
# 2         1.0             Andhra Pradesh          165433898.0
# 3         2.0         Arunachal\rPradesh             444005.0
# 4         3.0                      Assam            6052667.0
#
#    foreign_revenue_17  domestic_revenue_18  foreign_revenue_18  \
# 0                 NaN                  NaN                 NaN
# 1             15313.0             498279.0             15242.0
# 2            271362.0          194767874.0            281083.0
# 3              7147.0             512436.0              7653.0
# 4             21760.0            5856282.0             36846.0
#
#    domestic_growth_rate  foreign_growth_rate
# 0                   NaN                  NaN
# 1                  5.59                -0.46
# 2                 17.73                 3.58
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'state', 'domestic_revenue_17', 'foreign_revenue_17',
#        'domestic_revenue_18', 'foreign_revenue_18', 'domestic_growth_rate',
#        'foreign_growth_rate'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head()
# Out:
#                        state  domestic_revenue_17  foreign_revenue_17  \
# 0                        NaN                  NaN                 NaN
# 1  Andaman &\rNicobar Island             471919.0             15313.0
# 2             Andhra Pradesh          165433898.0            271362.0
# 3         Arunachal\rPradesh             444005.0              7147.0
# 4                      Assam            6052667.0             21760.0
#
#    domestic_revenue_18  foreign_revenue_18  domestic_growth_rate  \
# 0                  NaN                 NaN                   NaN
# 1             498279.0             15242.0                  5.59
# 2          194767874.0            281083.0                 17.73
# 3             512436.0              7653.0                 15.41
# 4            5856282.0             36846.0                 -3.24
#
#    foreign_growth_rate
# 0                  NaN
# 1                -0.46
# 2                 3.58
# 3                 7.08
# 4                69.33

# %%
df.drop([0], inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#                         state  domestic_revenue_17  foreign_revenue_17  \
# 0   Andaman &\rNicobar Island         4.719190e+05             15313.0
# 1              Andhra Pradesh         1.654339e+08            271362.0
# 2          Arunachal\rPradesh         4.440050e+05              7147.0
# 3                       Assam         6.052667e+06             21760.0
# 4                       Bihar         3.241406e+07           1082705.0
# 5                  chandigarh         1.425781e+06             31832.0
# 6                chhattisgarh         1.735003e+07              6701.0
# 7       dadra & nagar\rHaveli         6.141820e+05              1908.0
# 8                 daman & diu         8.581310e+05              5535.0
# 9                     delhi *         2.911442e+07           2740502.0
# 10                        Goa         6.895234e+06            842220.0
# 11                    Gujarat         4.834312e+07            448853.0
# ...

# %%
df.columns
# Out:
# Index(['state', 'domestic_revenue_17', 'foreign_revenue_17',
#        'domestic_revenue_18', 'foreign_revenue_18', 'domestic_growth_rate',
#        'foreign_growth_rate'],
#       dtype='object')

# %%
df['state']
# Out:
# 1     Andaman &\rNicobar Island
# 2                Andhra Pradesh
# 3            Arunachal\rPradesh
# 4                         Assam
# 5                         Bihar
# 6                    chandigarh
# 7                  chhattisgarh
# 8         dadra & nagar\rHaveli
# 9                   daman & diu
# 10                      delhi *
# 11                          Goa
# 12                      Gujarat
# 13                      Haryana
# 14            Himachal\rPradesh
# 15                    Jharkhand
# 16                          J&K
# 17                    Karnataka
# 18                       Kerala
# 19                  Lakshadweep
# 20               madhya Pradesh
# 21                maharashtra *
# 22                      manipur
# 23                    meghalaya
# 24                      mizoram
# 25                     nagaland
# 26                       odisha
# 27                   Puducherry
# 28                       Punjab
# 29                    rajasthan
# ...

# %%
df.to_excel(r'F:\Analytics\transerve assignmnts\tourism_data\tourism_2018_revenue.xlsx', index=False)
